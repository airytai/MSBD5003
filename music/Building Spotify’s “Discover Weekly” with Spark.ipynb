# %%
# Reference: https://towardsdatascience.com/building-spotifys-discover-weekly-with-spark-4370d5d0df2f
from pyspark.mllib import recommendation
from pyspark.mllib.recommendation import *

# %%
rawUserArtistData = sc.textFile("D:/HKUST/Big Data Computing/Project/Reference/MusicRecommendation-Spark--master/user_artist_data_small.txt")
rawArtistData = sc.textFile("D:/HKUST/Big Data Computing/Project/Reference/MusicRecommendation-Spark--master/artist_data_small.txt")
rawArtistAlias = sc.textFile("D:/HKUST/Big Data Computing/Project/Reference/MusicRecommendation-Spark--master/artist_alias_small.txt")

# %% [markdown]
# # Preprocess data

# %% [markdown]
# We want to obtain a list of raw artist data with each ID and name stored in tuples. Lets use artist_data.txt to create this list.

# %%
def pairsplit(singlePair):
    splitPair = singlePair.rsplit('\t')
    if len(splitPair) != 2:
        return []
    else:
        try:
            return [(int(splitPair[0]), splitPair[1])]
        except:
            return []
artistByID = dict(rawArtistData.flatMap(lambda x: pairsplit(x)).collect())

# %%
artistByID
# Out:
# {1240105: 'André Visior',
#  1240113: 'riow arai',
#  1240132: 'Outkast & Rage Against the Machine',
#  6776115: '小松正夫',
#  1030848: "Raver's Nature",
#  6671601: 'Erguner, Kudsi',
#  1106617: 'Bloque',
#  1240185: 'Lexy & K. Paul',
#  6671631: 'Rev. W.M. Mosley',
#  6671632: 'Labelle, Patti',
#  1240238: 'the Chinese Stars',
#  1240262: 'The Gufs',
#  6718605: 'Bali Music',
#  6828988: 'Southern Conference Featuring Dr. Ace',
#  1240415: 'Paul & Paula',
#  1009439: 'Cinnamon',
#  1018275: 'School Of Fish',
#  6671680: 'Armstrong, Louis & His Hot Five',
#  1240508: 'The Ozark Mountain Daredevils',
#  1240510: 'The Mercury Program',
#  1240516: 'Del Close & John Brent',
#  1002584: 'Nena',
#  6990766: 'Phil Hendrie - 11/06/98',
#  1240554: 'Ami Yoshida',
#  1124756: 'utabi',
#  10023740: 'Red & Blue feat. Cathy Dennis',
#  1240589: 'Sebastian Bach & Friends',
#  1240603: 'The Wake',
#  6748187: 'Eric Darling',
#  1238620: 'Juno Reactor, Don Davis',
#  10585028: '大友良英ニュー・ジャズ・クインテット',
#  10113150: 'wouter van veldhoven',
#  3055: 'Montag',
#  1240848: 'McFadden & Whitehead',
#  1240853: 'ORANGE RANGE',
#  10024032: 'Bobby Sutcliff',
#  1011119: 'Emergency Broadcast Network',
#  6671734: 'Alternate Main Title #3',
#  6671738: 'Dona Walser',
#  1159691: 'SID',
#  1240890: 'The Eyeliners',
#  1127179: 'Shotgun Remedy',
#  1240919: 'the Boondock Saints',
#  1240955: 'The Boondock Saints Soundtrack',
#  1240959: 'Miles Davis & Gil Evans',
#  1128549: 'Akia',
#  1241016: 'The Ducky Boys',
#  1241122: 'The Glove',
#  1136054: 'barrio chino',
#  1018840: 'Nick Heyward',
#  6671768: 'Jazzbo All Stars',
#  1082698: 'STM 200',
#  1118565: 'Jeff Black',
#  6884090: 'Lower Cut',
#  7004450: 'Craig Werner',
#  7031362: 'Piolts vs. Aeroplane',
#  7031363: 'Grinning Idiots',
#  7031364: 'DJ Krush Featuring Boss The Mc',
#  7031365: 'Beavis & Butt-head (Mike Judge)',
#  1011186: 'Commander Cody and His Lost Planet Airmen',
#  10025458: 'Emil Hyde',
#  1244352: 'The Æffect',
#  1244508: 'Teitur',
#  1244548: 'The Oval Portrait',
#  1244581: 'The Old Dead Tree',
#  1244582: 'Marc Carroll',
#  1244585: 'The Heavenly States',
#  1244627: "Hymie's Basement",
#  1049831: 'gregory fleckner',
#  1244749: 'Vaginal Incest',
#  1244907: 'Lindsay Lohan',
#  1244888: 'The Spongetones',
#  1244897: 'The Colour of Memory',
#  1244952: 'The Fiery Furnaces',
#  1244970: '01- Rachel s',
#  1244972: 'Desmond Decker & the Aces',
#  1244982: '03- Rachel s',
#  10025967: 'Southworth, John',
#  1245000: '08- Rachel s',
#  1245010: 'James Carter & The Prisoners',
#  1245026: 'The Pimps',
#  1245064: 'The Patti Smith Group',
#  1245081: 'UWA',
#  1245144: 'wrangler brutes',
#  1245117: 'Matt Valentine',
#  1110352: 'Jim Lauderdale',
#  10026118: 'Network Reps ft. Punch & Words',
#  1086856: 'Kurtis Mantronik presents Chamonix',
#  1245185: 'Joss Stone',
#  6962231: 'Kusse Guibada',
#  10586077: 'DJ.E.M.O.',
#  6715028: 'Baby Bumble Bee',
#  6767905: 'Sicilienne',
#  1245383: 'The Secret Stars',
#  1245426: 'The Exit',
#  1245557: 'The Move',
#  1137400: 'Chaise Lounge',
#  1245627: 'The Actual Tigers',
#  1262422: 'Wendy Bucklew',
#  1245657: 'Etwas',
#  10299597: 'Egodog',
#  1245697: 'Dosh',
#  1004467: 'Hypocrisy',
#  1245744: 'The Azoic',
#  1013348: 'Palace',
#  1016121: 'Sirenia',
#  1245770: 'Tuck & Patti',
#  10026670: 'Tornadoes 74',
#  10435425: '大島渚',
#  1013055: 'Pig',
#  1245897: 'The Bunch',
#  1246003: 'Eminem & D-12',
#  1068227: 'Bliss 66',
#  1246028: 'Jeanne & The Darlings',
#  3202: '2raumwohnung',
#  1093150: 'Antigone Rising',
#  1246094: 'The Collins Kids',
#  604: 'Ten Foot Pole',
#  1246101: 'Floyd Newman',
#  1235351: 'The Andrews Sisters',
#  1246185: 'The Impalas',
#  1246256: 'The Rosemarys',
#  10027022: 'E_O_H',
#  6671933: 'Mohamed Ray',
#  1044471: 'Eugene Chadbourne',
#  1246269: 'Red Peters',
#  1246290: 'Chobits Nanase Ohkawa',
#  1246301: 'Betsy',
#  1246307: 'Bash & Pop',
#  10027052: 'Chasing Zero',
#  6828997: 'Chuck Girard with Paul Johnson',
#  1246383: 'Chobits Katsutoshi Kitagawa',
#  1246394: 'Kronos Quartet With Chuck Israels And Eddie Marshall',
#  10586534: 'Klan Of Xymox',
#  1246478: 'The Choir',
#  1246483: 'Clint Ruin & Lydia Lunch',
#  1246497: 'The Tony Rice Unit',
#  3322: 'Stephen Bishop',
#  1000193: 'Saliva',
#  1246573: 'Wayne Fontana & the Mindbenders',
#  10027222: '香港男祭',
#  1246590: 'Kare Kano ACT 2.0',
#  1032459: 'Fin.K.L',
#  1029020: 'Total Devastation',
#  1138112: 'G. G. All Stars',
#  10027285: 'Test Pattern',
#  10027324: 'accidents in too large field',
#  1246719: 'The Loud Family',
#  1086845: 'Hanover Saints',
#  10236811: 'The Prodigy Vs Unknown',
#  1246870: 'Sleater-Kinney & Fred Schneider',
#  6991019: 'Green Scarab',
#  1246891: 'beatmania IIDX 4th style',
#  1246904: 'The Revolutionary Hydra',
#  1246914: 'Kevin Eldon',
#  1246937: 'Joolz Gianni & Ty Unwin',
#  6962264: 'Dale Thompson & The Kentucky Cadillacs',
#  1246950: 'The Roots of Orchis',
#  1246957: 'The Intima',
#  10027679: 'Gagalactyca',
#  1247016: 'the rockfords',
#  1247017: 'Nusrat Fateh Ali Khan & Party & Diamanda Gallas',
#  1247030: 'Eros Necropsique',
#  1247079: 'The Plus Ones',
#  1247125: 'Les Paul & Mary Ford',
#  6664945: 'Grupo Cantadores Do Redondo',
#  10586745: 'Robert Plant And The Strange Sensation',
#  1046513: 'Oh Susanna',
#  10008620: '堀下さゆり',
#  1247221: 'The Nazz',
#  1247272: '植松伸夫',
#  1138578: "Rockin' Tabby Thomas",
#  1003847: 'Imagination',
#  1247508: 'Chris Walken',
#  1247537: 'Merseys, The',
#  1247540: 'Filter & the Crystal Method',
#  1247572: 'The All',
#  1138719: 'Buddy Emmons',
#  1247649: 'ORIGINAL LOVE',
#  6868177: 'VA - Mixed By Simon Dunmore',
#  1839: 'Alabama 3',
#  1247732: 'Williamson',
#  1247869: 'Sifl & Olly',
#  1247879: 'Riggs',
#  658: 'George Duke',
#  1138844: 'Walter Davis',
#  10028569: 'Billy Pigg',
#  1247913: 'JamisonParker',
#  1247915: 'Don Campbell',
#  1247973: 'Ricky Martin & Christina Aguilera',
#  1116416: 'Combine',
#  1248043: 'red sleeping beauty',
#  6672234: 'Sacred Flute Music From New Gu',
#  1220059: 'Dick Hyman Group and Howard Alden',
#  6672253: 'Poulopoulos',
#  1248149: 'Macho Man Randy Savage',
#  1248160: 'The Heartbreakers',
#  6870433: 'Grand Finale',
#  1248224: '青木麻由子',
#  1248243: 'Kate St. John',
#  1248245: 'The Three Amigos',
#  1039016: 'altern 8',
#  1248283: 'The Magpies',
#  6672280: 'Sammy Kaye & his Orchestra',
#  1248302: 'Smokey & Miho',
#  1035419: 'Jorge Ben Jor',
#  1248390: 'The Starseeds',
#  1248452: "D'gary & Jihe",
#  1248467: 'The Vaughan Brothers',
#  1135590: 'vast air',
#  1248512: 'Phillip Boa & The Voodoo Club',
#  6776133: 'ピンク・ピクルス',
#  10029232: 'The Rich Mullins Project',
#  1139201: 'Greek folk',
#  1139203: 'Hank Flamingo',
#  10029365: 'Don Diablo - Fade Away',
#  7031661: '添田知道',
#  6672437: 'Communic',
#  1248866: 'New Artist (483)',
#  1001701: 'Left Front Tire',
#  1248871: 'The Crucifucks',
#  1248875: 'Jesus Alemany',
#  1324655: 'Annie Stela',
#  6869119: "Zhane'",
#  7031711: '坂本ハツミ',
#  1026352: 'Asha Bhosle',
#  10030151: 'Michael Torke/John Harle (saxophone), Albany Symphony Orchestra',
#  1249103: 'Satellites of the Stone Age',
#  1249185: 'Amy Goodman',
#  1249247: 'Punky Brusster',
#  1249252: 'The Susan Tedeschi Band',
#  1249308: 'Bob Wills & His Texas Playboys',
#  9979298: 'The Three Stooges.',
#  1249335: 'Bonnie Raitt And Was (Not Was)',
#  9979300: 'Sometimes You Feel Like A Nut',
#  6860529: 'Joaqu匤 D僘z',
#  1249389: 'Far-Less',
#  6672509: 'Traditionnel',
#  9979309: 'Do You Know Exactly How',
#  9979310: 'The Mariner',
#  1249463: 'robert pollard and his soft rock renegades',
#  1249561: 'never alone',
#  6715280: 'Mountain Ash Band',
#  9979317: 'Ozzy & Sharon Osbourne',
#  6864536: 'The Cortinas',
#  9979319: 'Meow Meow Meow Meow',
#  1249648: 'Trio Töykeät',
#  1249654: 'Y&T',
#  10584463: 'A/D Abe Dolinger',
#  10237098: 'Indigo Girls & Micheal Stipe',
#  9979324: 'Candy Coated Popcorn, Peanuts And A Prize',
#  1034846: 'Diva Destruction',
#  1249966: 'The Sun',
#  1249975: 'Steve Angello',
#  10587892: 'Collins Albert',
#  1250037: 'O-Matic',
#  6672661: 'Antonio Carlos Jobim+Sting',
#  9979335: 'Stronger Than Dirt',
#  9979338: 'Winston Tastes Good',
#  1038366: 'Caleb',
#  10008728: 'Mighty Moguls',
#  1250135: 'John Prine & Iris DeMent',
#  9979341: 'The Marlboro Song',
#  1140199: 'Edan 6 Day',
#  2193: 'Electric Company',
#  1250223: 'Jason Gleason',
#  1250361: 'Chad & Jeremy',
#  1250384: 'Mark Davis',
#  1250412: 'Chain Gang',
#  1132792: 'Canibus Nas and Nature',
#  1250955: 'The Georgia Satellites',
#  1251059: 'The Rogers Sisters',
#  1094793: 'My Hotel Year',
#  1140492: 'Blue Rose',
#  1251256: 'Henri Rene & His Orchestra',
#  6672801: 'Sound Machine',
#  1251270: 'Relaxation Music-Laputa',
#  1188155: 'NAHT',
#  1251361: 'Aly Bain & Phil Cunningham',
#  6672865: 'Fugue In G Minor',
#  1251473: 'Body & Soul',
#  10031640: 'Jenny Gullen/Derri Daugherty',
#  1251568: 'Depeche Mode & New Order',
#  1251573: 'The Sugarhill Gang Vs. Grandmaster Flash & The Furious Five',
#  10031718: 'Jerry Jeff Walker & Austin Lounge Lizards',
#  6776169: '白石冬美・スラップスティックス',
#  1251612: 'WNB',
#  1251637: 'Liz Janes',
#  1251657: 'Jason Molina',
#  2855: 'Nigel Kennedy',
#  1251691: '石川さゆり',
#  6672866: 'Nairobi Beat',
#  6930873: 'Alice Through The Looking Glass',
#  1020207: 'Consonant',
#  1251822: 'Christine Albert',
#  1251846: 'Fernando Antonio Pearson',
#  1251883: 'Rainey, Ma',
#  1251900: 'The Ex',
#  1251918: 'Mimi & Richard Farina',
#  1251952: 'Emmylou Harris, Alison Krauss & Gillian Welch',
#  1031182: "Lil' Kim",
#  7031858: 'Dick Liebert',
#  10032129: 'the new rock project',
#  1252000: 'Nirvana, Sonic Youth & REM',
#  10032273: 'Maraca(Orlando Valle)',
#  10032332: 'A PIECE OF SHIT',
#  10032353: 'Conjunto Folklorico Nacional de Cuba',
#  10032374: 'Mendoza Y Los Papines, Celeste',
#  10032392: 'Comparsa San Agustin',
#  1252109: 'Stille Volk',
#  10032401: 'Valdes Y El Grupo De Jose Maria Vitier, Merceditas',
#  6909804: 'Punjabi Dance Mix',
#  6909810: 'Marc Landsman',
#  10032416: 'Bola de Neve',
#  10436601: 'Michael Tiernan',
#  1026939: 'Bobby Blue Bland',
#  6673039: 'Spriguns',
#  1252229: 'Coach Z',
#  135: 'Motorbass',
#  1004461: 'Gary Jules',
#  10476267: 'Glenn Miller & The 418th AAFTC Band',
#  1252420: 'The Ordinary Boys',
#  10476256: 'Mr. Gasser & The Weirdors',
#  205: 'Hacienda',
#  10476266: 'Jeri Sullavan',
#  10008827: 'Julie Henigan',
#  10476265: 'Al Trace & His Silly Symphonists',
#  1252523: 'The Sights',
#  10237340: 'Pererin',
#  1252557: 'Ann & Nancy Wilson',
#  410: 'Red Snapper',
#  1252587: 'Puscifer',
#  1252607: 'bexar bexar',
#  1252764: 'The Smoking Popes',
#  1252774: 'Ziggy Marley & The Melody Makers',
#  1252783: 'The Records',
#  1252808: 'Juno Reactor & Don Davis',
#  9934695: 'Eric in Frisco',
#  1252873: 'Sakerock',
#  1252911: 'Marc Almond & Foetus',
#  10237382: 'Near Nora',
#  10476465: 'Bennassi Bros Presents The Biz',
#  1253023: 'The Velvet Crush',
#  1253025: 'Casting Crowns',
#  1253035: 'Eddie Holland',
#  1253062: 'Words on Music',
#  10151898: 'Driftnet',
#  1253129: 'The Beat Junkies',
#  1253134: 'Taranchula',
#  7031948: 'James Shadko',
#  1253188: 'The Penguins',
#  7031958: '添田知道、小沢昭一',
#  2998: 'King Britt',
#  1253230: 'The Iguanas',
#  1253239: 'Big Black Beat',
#  1253284: 'Café Del Mar',
#  10186740: 'Richard Galliano, Eddy Louiss',
#  10300597: 'Glaser, Tompall',
#  1000658: 'Squeeze',
#  1253504: 'Southside Johnny & The Asbury Jukes',
#  1030650: 'Hard Knox',
#  1253563: 'THE SAINT',
#  1153396: 'Pipkins',
#  1253631: 'Kayo',
#  1134975: 'Mac 10',
#  1160555: 'Secret Weapon',
#  1253792: 'The Rutles',
#  1253809: 'The Rurals',
#  1253817: 'Aquasky Vs. Masterblaster',
#  1000306: 'Danny Wilson',
#  7032006: 'Plat Ypus',
#  1253915: 'boogiepop phantom ost',
#  6950486: 'Full On Venus',
#  1169311: 'Weathertunes',
#  10237528: 'Licksmiths',
#  1253965: 'Civil Disobedience',
#  10237553: 'Boyrace',
#  1065838: 'THD',
#  10237540: 'Orgami',
#  4305: 'Jim White',
#  7032059: 'Burl Ives with Percy Faith & His Orchestra & Chorus',
#  1254125: 'The Hope Blister',
#  1254139: 'Vaughn Monroe',
#  6724692: 'Ruby Joe',
#  1078966: 'Johnny Clegg and Juluka',
#  1254189: 'Komatsu Rika',
#  1254195: 'Rika Komatsu & Miscellaneous Artists',
#  1254235: 'The Candy Skins',
#  1254241: 'Lorraine Lewis',
#  1254266: '32 Degrees In Hell',
#  1254299: 'The Word',
#  1254364: 'Marty McFly with the Starlighters',
#  10237603: 'Putney Swope',
#  1254441: 'The Power Station',
#  1254488: 'The Rosenbergs',
#  6776208: 'KYOZO&BUN, 大塚まさじ, 加川良',
#  1257270: 'Le Mystère des Voix Bulgares',
#  1051762: 'Jeremy Enigk',
#  1234278: 'The (International) Noise Conspiracy',
#  10477997: 'Didier Pauvert and Michel Esbe',
#  1254665: 'Nina Persson',
#  1238759: 'The Brand New Heavies',
#  1000096: 'Arturo Sandoval',
#  1254886: 'Peter & Gordon',
#  6902384: 'B.O.N.E. Thugs-N-Harmony',
#  7032146: 'Andre Kostelanetz & His Orchestra with The St. Kilian Boychoir and Phyllis Curtin, Soloist',
#  1254952: 'The Sleeping',
#  1255038: 'Seekonk',
#  1255111: "Don't Run",
#  1255114: 'foreverDOWN',
#  1255123: 'Death Before Dishonor',
#  1255130: 'The Fleetwoods',
#  6748205: 'excliam',
#  1255198: 'Comity',
#  1255278: 'The Fall Project',
#  1255281: 'This Moment',
#  1011179: 'Shawn Mullins',
#  1255312: 'Flaco Jiménez',
#  1255313: 'Cath Carroll',
#  1255314: 'Mezo',
#  1255401: 'Afrika Bambaataa & The Soul Sonic Force',
#  1011441: 'Rites of Spring',
#  1255417: 'The Nat King Cole Trio',
#  6715089: 'Dizzy Gillespie & Ella Fitzger',
#  1255443: 'Tom Jones & Pretenders',
#  1255445: 'Che-SHIZU',
#  1255533: 'Dżem',
#  6832429: 'Sound Wars',
#  1255551: 'Stan Getz & Joao Gilberto Featuring Antonio Carlos Jobim',
#  1255601: 'Ill Bill Feat. Necro',
#  1255602: 'Mr. Hyde Feat. Necro',
#  10581396: 'JK & Co.',
#  10478283: 'A Chidlhood Lost',
#  6702906: 'Markos Vamvakaris',
#  1253603: 'The Maddox Brothers and Rose',
#  1255757: 'Anthony Hamilton',
#  1164236: 'Waking Kills The Dream',
#  1255808: 'The Pinkerton Thugs',
#  1255883: 'Starbelly',
#  6714255: 'jim kweskin and the jug band',
#  1033983: 'Calendar Girl',
#  10478357: 'The Used/My Chemical Romance',
#  1255953: 'Tammany Hall NYC',
#  1255972: 'John Cena',
#  1030197: 'Slave Unit',
#  1256011: 'At A Loss',
#  1256033: 'Ashen Mortality',
#  1256058: 'The Prayer Chain',
#  1256080: 'Rednex.',
#  1256111: 'Martin Carthy & Dave Swarbrick',
#  1256131: 'JOJO',
#  1210509: 'Mark Williams',
#  1125619: 'Bobby Troup',
#  1030334: 'Gene Vincent',
#  1256211: 'Тату на Плюке',
#  1256267: 'Hollywood Studio Symphony',
#  1238488: 'the tiny',
#  1256365: 'The Sems',
#  6991547: 'L.L. Cool J With Flea, Dave Navarro And Chad Smith',
#  1256392: 'Benny Goodman Trio',
#  6895972: 'Hill, Terry & Salad',
#  1256509: 'Би-2',
#  1256524: 'The Prize Fighter Inferno',
#  10186899: 'Stanley Mitcheell & The Tornados',
#  1008950: 'Corrosion Of Conformity',
#  1015185: 'Susperia',
#  5172: 'Cinerama',
#  1303360: 'Carolyn Crawford',
#  10113939: 'Funky Greeen Dogs',
#  1256992: 'Salmon',
#  10113944: 'The J-Mad Cozmo Experience',
#  1257045: 'Thread Of Hope',
#  1257059: 'The Bacon Brothers',
#  1257062: 'The Spill Canvas',
#  5735: 'Robert Ashley',
#  10438210: 'Belinda Carlisle & Radiator',
#  7032254: 'Leslie Pearson, organ; John Paice, carillon; Westminster Brass Ensemble',
#  1257166: 'Coldcut & Hexstatic',
#  1065609: 'Jimmy Weckl',
#  7005139: 'The Breaux Freres (Clifford, Ophy, Amedee)',
#  1257252: 'Nyarlathotep',
#  10479335: 'Pictures Of Shorelines',
#  1257264: 'Audra Kubat',
#  1011238: 'Shudder To Think',
#  1257324: 'The Mission U.K.',
#  1257410: 'tomandandy (ft. Kip Pardue)',
#  6918119: 'Earl Chandler',
#  1257454: 'The Weathermen',
#  1257486: 'Kenna - 01',
#  1257521: 'ДДТ',
#  6673689: 'Lang, Peter',
#  6776262: '至福団',
#  10479543: 'The Litigators',
#  1257559: 'The Stairs',
#  1257607: 'The Jaynetts',
#  1027343: 'Melanie Doane',
#  1124005: 'Heroes',
#  1257694: 'Joe Louis Walker',
#  1257729: 'Béla Bartók',
#  10479660: 'Patyy Griffin',
#  1257832: 'Blackman, Destruct & Icon',
#  1257837: 'realized',
#  1257851: 'de portables',
#  1011070: 'Tracy and the Plastics',
#  6776274: 'Waltz for Eva and Che',
#  1003950: 'Dark Tranquillity',
#  1258010: 'Archie Bronson Outfit',
#  10479805: 'ジャンクションピーク',
#  1258061: 'Heavy D & the Boyz',
#  7005169: 'Frank Cloutier & The Victoria Cafe Orchestra',
#  10479818: 'モノノフルーツ',
#  1258072: 'The Siren Six!',
#  516: 'Focus',
#  6673741: 'Chaotic Discord',
#  1258246: 'The Associates',
#  6673759: 'Kip Anderson',
#  1258350: 'Percy Faith & His Orchestra',
#  6673788: 'Pete Sears',
#  6673789: 'Acoustic Hot Tuna',
#  10479977: 'パイナップルフリーウェイ',
#  6673828: 'Ralph Stanley & Dwight Yokum',
#  1258418: 'The Communards',
#  10438678: '紅月ノリコ',
#  1179272: 'Fem 2 Fem',
#  1258439: 'The Magnificents',
#  6673869: 'Steve McClintock',
#  10438684: 'Tony Adams (Radio Edit)',
#  1258491: 'Brancaccio & Aisher',
#  1258509: 'The Rock Steady Crew',
#  10480075: '太陽民芸',
#  1258632: 'Shattered Faith',
#  6873629: 'Nikki Sudden & The French Revolution',
#  1258649: 'Alec Empire & Techno Animal',
#  1071539: 'N.M.R.',
#  1144580: 'World',
#  1258740: 'Speed, Glue & Shinki',
#  1258743: 'Gaudino feat Crystal Waters',
#  1258778: 'ORANGENOISE SHORTCUT',
#  1258796: 'Moonscape',
#  10152228: 'Ralphie Boy',
#  10480249: 'Remembering Tonight',
#  1029939: 'Stretch Princess',
#  1258938: 'The Jive Five',
#  9918583: 'Cedric "K-Ci" Hailey',
#  1105592: 'Kutmasta Kurt Presents Masters Of Illusion',
#  6802804: 'Hockley Hustlers',
#  1210706: "Dan Severn's Broken Neck",
#  9934860: 'Be A Pepper',
#  1259199: 'Roger Clyne & the Peacemakers',
#  9951565: 'Kiss Me, Miss Liberty',
#  1071195: 'Julie Doiron and the Wooden Stars',
#  10187095: 'Sincerely Paul',
#  1554: 'Cave In',
#  2050483: 'Violent Headache',
#  1259410: 'The Twin Atlas',
#  1259423: 'Angels & Agony',
#  1681: 'Reef',
#  1259455: 'Michael Bublé',
#  1259495: 'Thuggie D.',
#  732: 'Neneh Cherry',
#  1259522: 'Les VRP',
#  1259569: 'Chad Michael Murray',
#  6658178: '中川イサト',
#  6860330: 'Caleb Sampson - Eternal Future',
#  6860322: 'Delroy Wilson, Slim Smith',
#  1259609: 'C.J.Crew feat.Sedge',
#  1204775: 'Aerospace',
#  1080950: 'Easy',
#  1259638: 'YAMACHAN WITH JIMUSASUHIKARU',
#  6660422: 'Lolita Ritmanis',
#  6892356: 'Ilmari & Salyu',
#  6873381: 'Choad Effect',
#  6674079: 'My Folder',
#  1260003: 'Mercury Switch',
#  1260023: 'Reid Paley',
#  1260083: 'Purple Hearts',
#  9979937: 'Metal Gear Solid 2; Substance',
#  1260344: 'No Vacancy',
#  1260370: 'The Fellowship',
#  1260379: 'Prassay',
#  1003970: 'Pungent Stench',
#  1260480: 'DAN I',
#  1260489: 'The Exciters',
#  1260548: 'Rainy Day Crush',
#  1260572: 'Nightmare Of You',
#  1260614: 'Dr. & the Medics',
#  1260625: 'Fireworks',
#  1008529: '1000 Homo DJs',
#  9979947: 'Micheal Nyman - The Heart Asks Pleasure First The Promise',
#  10590378: 'Vinnie Paz & Louis Logic',
#  1260661: 'Robbie Robertson & The Red Road Ensemble',
#  1260737: 'The Magic Magicians',
#  1038823: 'Beck and Emmylou Harris',
#  1260832: 'balkan beat',
#  1385: 'Scarface',
#  2018: 'Da Lench Mob',
#  1237561: 'The Handsome Family',
#  1260909: 'Tomash Gee',
#  1260924: 'DJ Vadim & Mark B',
#  1118714: 'Mazi',
#  1261091: 'The Psyke Project',
#  1261139: 'The Percentie Brothers',
#  1261140: 'Mighty Panther',
#  1261147: 'Calypso Mama',
#  9979971: 'Goodie Mob + Outkast',
#  1261188: '鄭秀文',
#  1261201: 'Seymour',
#  1261208: 'Jimmy Earl',
#  1244756: 'Alex Parks',
#  1261244: 'Paintbox',
#  1261259: 'Soulmate',
#  1261261: 'Ron van den Beuken',
#  10590759: 'Muddy Frankenstein',
#  1261284: 'All-Star Band Of Cajun Musicians',
#  1261288: 'Ann Savoy',
#  1261388: 'Mark Lane',
#  6719165: 'Geoff Hawryluk',
#  1261449: 'The Shadows Of Knight',
#  6903313: 'MUSICA TRANSONIC & ヤマンタカEYE',
#  1261461: 'Bathtub Shitter',
#  1261496: 'J-Kwon',
#  1261534: 'Carrie',
#  1261559: 'A Sense Of Belonging',
#  10481387: 'Sweet Home Chicago (Honeyboy Edwards)',
#  1261703: 'The Spent Poets',
#  1051103: 'Iluvatar',
#  1261794: 'Russ Taff',
#  1261803: 'Caninus',
#  1010658: 'Kitaro',
#  10590964: 'ORdER・BOLLOCKS',
#  1261918: 'Robinella & The CC String Band',
#  1261962: 'The Timewriter',
#  1262039: 'Stray From The Path',
#  1262067: 'Peter Astor',
#  1262090: 'Civil Tones',
#  1262123: 'Valley of the Giants',
#  1262115: 'Electro Assassin',
#  1262203: 'SI Randere',
#  1262244: 'Conducted by George Fenton',
#  1262267: 'Curtis Mayfield & The Impressions',
#  1262279: 'Living Better Electrically',
#  1262293: 'Dan Bryk',
#  1043914: 'Petty Booka',
#  9980034: 'bil fay',
#  9980035: 'Fresh Blueberry Pancake Heavy',
#  6930961: 'King Size Taylor & The Dominoes',
#  1262397: 'Jack Hardy',
#  9918683: 'Big Twan',
#  1262420: 'Dying Tears',
#  1262458: 'Nephasth',
#  1262473: '那英',
#  1262514: 'Gillian Welch ~ Alison Krauss',
#  7005354: 'Tom Jones vs. Funkstar Deluxe feat. DJ the Wave',
#  1262561: "Sabotage - Qu 'Est - Que C'est?",
#  1262575: 'The Civilian Project',
#  1262601: 'Patricia Vonne',
#  1000300: 'Mountain',
#  10033576: 'Art Neville & The Meters',
#  6674381: 'Maddy Prior/R Kemp',
#  1262640: 'H.P. Lovecraft Historical Society',
#  1262646: 'Rani Arbo & Daisy Mayhem',
#  1262652: 'Smith, Kendra',
#  1262671: 'Del Castillo',
#  1099116: 'Central Services',
#  10481846: 'BLACK EYE PEAS VS THE STELLAR PROJECT 2004 MIX',
#  1262714: 'Les Sampou',
#  10592278: 'Frankie Lymond & the Teenagers',
#  1262727: 'Jo Ann Kelly',
#  6991867: '東方沙羅',
#  10114271: 'KARMA STENCH',
#  1262767: 'David A. Stewart Feat. Candy Dulfer - Lily Was Here',
#  1262818: 'Gratitude',
#  6674419: 'Kenny Burrell/medeski Martin &',
#  6903356: 'Jugz',
#  1262877: 'Caterwaul',
#  4538: 'Armand Van Helden',
#  1262913: 'Ffa Coffi Pawb',
#  1262922: 'Hollyfaith',
#  10481912: 'Ultrabeat Vs. IIO',
#  1262964: 'Quran',
#  10592539: '日暮愛葉÷中村弘二',
#  10592593: 'Atomic Orchestra',
#  10592603: '清水一登',
#  10592634: 'Sizk',
#  1263001: "Jitterin' Jinn",
#  1018934: 'Llorca',
#  10592523: "Otomo Yoshihide's New Jazz Ensemble Featuring Kahimi Karie",
#  1263049: 'The Voluptuous Horror Of Karen Black',
#  1263059: 'Decrepit',
#  10592562: 'ハミングキッチン＋とらジャム',
#  1111165: 'Mayuko Aoki, Marika Matsumoto, Rio Natsuki',
#  9980080: '903号室',
#  1263100: 'Shining (feat. Julian Beeston, Ex Nitzer Ebb)',
#  1263106: 'Salute The Dawn',
#  7005387: 'Didier H饕ert',
#  1263154: 'Crossfade',
#  1263168: 'The Derek Trucks Band',
#  6674511: 'Proof Of Existence',
#  1332: 'Teengenerate',
#  6674531: 'Papa Too Sweet and Harry Jones',
#  1263207: 'Arsis',
#  1203392: 'Air This Side Of Caution',
#  1263296: 'La Chimera',
#  1263316: 'Noisy Little Sunbeams',
#  1263324: 'Ditch Croaker',
#  1263340: 'Blue Rags',
#  1263344: 'Trish Murphy',
#  1263375: 'Wendy Woo',
#  1263379: "Can't Stop Killing You",
#  1263413: 'Jack White',
#  10593320: 'Plastic Machine',
#  1263430: 'Tom Jones & Mousse T',
#  10114321: 'DIG A HOLE',
#  1263536: 'My Lost Home In Your Arms',
#  1263582: 'Mark Erelli',
#  1263600: 'Xaviera Hollander',
#  1263641: 'The PrizeFighter',
#  1263646: 'The Fight',
#  1263658: 'Jean Micheal Jarre - Oxygene IV',
#  7005429: 'Ernest V. Stoneman, Hattie Stoneman',
#  1263682: 'Operator, Operator',
#  6692672: 'Penelopes',
#  6770725: 'the department of homeboy security',
#  1263753: 'Zoe Lewis',
#  1263780: 'KGSR',
#  1263805: 'Steve Earle and the Del McCoury Band',
#  1263808: 'Peter Malick Group Featuring Norah Jones',
#  6806711: 'Frak Tovey And The Pyros',
#  1263850: 'The Gypsymen',
#  1263924: 'New Hawaiian Band',
#  9980147: 'Put a Little Love in Your Heart - Leonard Nimoy',
#  1264007: 'Live From New York',
#  1264025: 'The Planet The',
#  6818933: 'Tarheel Slim & Little Ann',
#  1135387: 'Freudstein',
#  1264080: 'Sub Fusion',
#  1264113: 'Theo Bikel',
#  1011023: 'Giorgio Moroder',
#  1264145: 'Buddy Mondlock',
#  1264162: 'The Legendary Shack Shakers',
#  10594517: 'Good Times Bad Times-Cracker',
#  1012494: 'POLYSICS',
#  1264214: 'Sam Pacetti',
#  9980171: 'The Molltarls',
#  1264285: 'Adiemus - Adiemus',
#  1264319: 'Timbuktu feat. Chords & Suprem',
#  10440244: 'Karin Wright',
#  1264363: 'Maho Neitsyt',
#  7005487: 'Cleoma Breaux, Joseph Falcon',
#  1025754: 'Royal City',
#  1010807: 'Need New Body',
#  1251192: 'Musica Transonic',
#  1264424: 'Radiosonde',
#  1264429: 'Excruciating Terror',
#  1109048: "Keb Mo'",
#  1264583: 'gus till',
#  1029629: 'Charlie Feathers',
#  6674795: '정태춘, 박은옥',
#  10595313: 'Satanyanko',
#  926: 'Souls of Mischief',
#  1237516: 'The Prodigy & Tom Morello',
#  6714809: 'The Close-Ups',
#  9918753: 'DJ RocRaida',
#  1264687: 'Trinkets Of Joy',
#  9918754: 'The Sundays ',
#  1264703: 'The Soviettes',
#  6727233: 'Proxima Estacion',
#  1018635: 'Pro-Pain',
#  1026832: 'Luxt',
#  1264751: 'Bellyfeel',
#  1264778: 'Gus Black',
#  1264909: 'Devin Townsend/Punky Brüster',
#  9951887: 'Revillosllos',
#  1264954: 'Heather Eatman',
#  1264986: 'Greg Garing',
#  1264989: 'Ollabelle',
#  1265006: 'Templars -',
#  1265024: 'A. J. Roach',
#  1265086: 'Seymores',
#  1265100: 'Morrissey and The Smiths',
#  1265213: 'Gibb Droll',
#  1265223: 'The Esoteric',
#  1265233: 'The Devlins',
#  1265249: 'Milady',
#  1265277: 'the mohawks',
#  1001941: 'The Drifters',
#  1247458: 'The Gun Club',
#  1265336: 'Sarah Harmer with The Tragically Hip',
#  1265407: 'Lucy Van Pelt',
#  5488: 'Dudley Moore',
#  1265416: 'Clemek Feat. Clé',
#  10440491: 'Patti Cathcart - Tuck Andress',
#  9951924: 'Celeste Mendozza',
#  1264223: 'Angry Johnny & the Killbillies',
#  1393: 'Laurent Garnier',
#  1265550: 'Fizzbin',
#  1265566: 'Kristen Hall',
#  6667324: 'Foam',
#  1265675: 'Rani ArboLimo To Memphis',
#  10440556: 'Jack Canfield & Mark Victor Hansen',
#  10114485: 'Ryan Adams (Feat. Emmylou Harris)',
#  6940517: "I'll Try (Reprise)",
#  1008014: 'Pino Donaggio',
#  1265779: 'Ellis Marsalis',
#  1141345: 'Bruno Lazzaretti/Danielle De Niese',
#  1234319: 'Hi Five',
#  1141408: 'R.E.M. and Radiohead',
#  1265876: 'Trivia Contest',
#  1265923: 'Porter Rockwell',
#  1265924: 'Total Resistance',
#  1265956: 'Storm, Inc.',
#  7005589: 'Cleoma Breaux, Joseph Falcon, Ophy Breaux',
#  6829068: '喜納昌吉＆チャンプルーズ',
#  6898700: 'Capt. Spaulding',
#  1266069: 'fragmented',
#  1266090: 'Soundtrack - Good Will Hunting',
#  1266111: 'Streets Most Wanted',
#  1031688: 'Metrovavan',
#  1266115: '08-Lovage',
#  1266122: 'The Craze',
#  1266128: 'Hifana',
#  6992072: 'angle',
#  1266150: 'Chesnutt, Mark',
#  1266190: 'Peaches & Herb',
#  1266304: 'REM & Natalie Merchant',
#  1266410: 'The Blackouts',
#  1266412: 'Embalming Theatre',
#  1266421: 'Dawson',
#  10114527: 'Putrid Scum - Putrid Scum',
#  1090130: 'DJ Neo',
#  1266516: 'American Water / The Silver Jews',
#  1266541: 'Danny Tenaglia ft Nick Warren',
#  1266566: 'Graig Markel',
#  1266595: 'G, Mike',
#  1266698: 'The Moon',
#  1266726: 'Carlinhos Brown',
#  1266739: 'Günther',
#  1266888: 'love peace and poetry (vol. 4)',
#  1266891: 'CSR SO/Lenárd',
#  1142902: 'Misty Mountain Hop-4 Non Blondes',
#  1266937: 'Koeda',
#  1266940: 'Madonna vs Kylie Minogue',
#  10483142: '=)',
#  1266958: 'Baja Mali Knindza',
#  2817: 'Adam F',
#  1267018: 'Rush Limbaugh   Paul Shanklin',
#  1267147: 'The Lovemakers vs. Roughshod',
#  6679210: 'Joe Ely & Uncle Tupelo',
#  1267222: 'Tom Jones & Stereophonics',
#  10483174: 'The Original Brady Bunch Kids',
#  1215929: 'World Domination Enterprises',
#  1239687: 'The Buzzhorn',
#  1267320: 'Eileen Hemphill-Haley',
#  1267324: 'Spirit of the Street',
#  1267338: 'Portable',
#  1267346: 'Nerissa & Katryna Nields',
#  1064428: 'Embalmer',
#  1143776: 'Djeli Moussa Diawara',
#  1267362: 'Carol Nethen',
#  1267384: 'Blue Flannel',
#  1267414: 'The Put-Outs',
#  1267504: 'JAY FARRAR  5/12/01',
#  1267516: 'Meswear',
#  1267542: 'The Snake the Cross the Crown',
#  1267567: 'Left Out',
#  1267569: 'Bartoli, Cecilia',
#  1075658: 'Letterman',
#  1267666: 'Neolithic',
#  6918162: 'Kathy Bull',
#  1232452: 'Oxidised Razor',
#  1144221: 'Johnny Crawford',
#  1267774: 'Sinéad Lohan',
#  1267880: 'The Pierces',
#  1267889: 'Глюкоzа',
#  1267900: 'The Pulsars',
#  1144582: 'Colum Sands',
#  1235339: 'The Saturday People',
#  1268098: 'The High Speed Scene',
#  1154836: 'Spaceboy',
#  1268143: 'The Last Emperor',
#  1144877: 'New American Shame',
#  1144888: 'aquarian dreams',
#  6700319: 'Stephen Bruton',
#  2115116: 'Fancey',
#  10187616: 'crossbred',
#  1285774: 'D-Cay',
#  1268268: 'David Thrussell',
#  1268279: 'Jimmy Lafave',
#  1268293: 'Seraphim Suite',
#  1268356: 'Punjabi Mc (DEPM.net)',
#  1110328: 'Fine China',
#  1145383: "Gene O'Quin",
#  1145473: 'Lumidee ft. 50 Cent',
#  10239117: 'Dylan, Bob & Johnny Cash',
#  1256995: 'King Chango',
#  1268466: 'Orissa',
#  1268469: 'The Larks',
#  1268488: 'Christine Kane',
#  1268554: 'Elvis Presley vs. Junkie XL',
#  1268592: 'The Music Machine',
#  1268611: 'Cazuza & Bebel Gilberto',
#  1268720: 'The Gothic Archies',
#  1176037: 'Yasuaki Shimizu',
#  1069836: 'Early Day Miners',
#  1268855: 'Historic Moments',
#  1268967: 'Classical Thunder - Holst',
#  1146216: 'Steve Tilston',
#  1095681: 'Silverjet',
#  1269086: 'Once Hush',
#  1151011: 'Fred Johnson',
#  5496: 'Echo & the Bunnymen',
#  1269171: 'Progress 1',
#  1017624: 'SQ-1',
#  1054753: 'Deceased',
#  1238993: 'Szymon Wydra & Carpe Diem',
#  1269306: 'Mylon & Broken Heart',
#  1269308: 'The Silencers - Wild Mountain Thyme',
#  9952088: "Curateto d'Adia",
#  1269417: 'The Dust of Basement',
#  1146750: 'Emile Vacher',
#  1269421: 'Rawkus feat. Fletch Digga',
#  1146752: 'Le Denecheau Jase Musette',
#  1269446: 'Checkfield',
#  1269466: 'Bruce Springsteen & Tom Waits',
#  1020930: 'Mescalinum United',
#  1269591: 'Strawberry Zots',
#  1269592: 'Oberon',
#  1269642: 'Janeane Garafalo & Ben Stiller',
#  6760306: 'Slowdance',
#  1147110: 'Troublemen',
#  6675309: 'Ronnie LANE & SLIM CHANCE',
#  1269760: 'Jim Henry',
#  10114700: 'Brother Love Canal',
#  1147307: 'Kuti, Fela Anikulapu',
#  1147329: 'King Sunny Ade and his African',
#  1239047: 'THE OLIVIA PROJECT',
#  1269971: 'Garrison Star',
#  1147547: "Pickin' On Zeppelin",
#  1231177: 'Lost Highway Soundtrack',
#  1270050: 'Electro Headz',
#  1270095: 'Shorthanded',
#  1147614: 'Steve Briody',
#  1147624: 'AccordionMan',
#  1001891: 'Elvis Costello & the Attractions',
#  1004346: 'Joshua Redman',
#  1043187: 'Doctor Who',
#  1147689: 'Don White',
#  1165635: 'Maher Shalal Hash Baz',
#  1270181: 'Los Nachos',
#  1270191: 'Othar Turner',
#  1270226: 'Dick Dale & the Del-Tones',
#  1270215: 'Luptacik/Capella Istropolitana/Edlinger',
#  1270220: 'Syd Matters',
#  1270222: 'The Great Depression',
#  1147770: 'Ryan Downe',
#  1270342: 'Stand by Me - Cassius Clay',
#  1270359: 'Silkworm - Hangman',
#  1270390: 'Gillian Welch & David Rawlings',
#  1270419: 'Back Porch Records Sampler 200',
#  1028156: 'Wanda Jackson',
#  1270464: 'Spider John Koerner & Dave Ray',
#  1270476: 'The Swarm',
#  1270503: 'Pierce Pettis',
#  1270505: 'Clark Kent',
#  1270506: 'John Cameron Mitchell & Step..',
#  1270512: 'Heather Kropf',
#  1270513: 'Billy Price',
#  1270514: 'Jabali Afrika',
#  1270516: 'Carol Lee Espy',
#  1270517: 'Shari Richards & Ernie Hawkins',
#  1270520: 'Liz Berlin',
#  1270521: 'Swinging Steaks',
#  1105668: 'Des-Row',
#  1270522: 'Russ Meyer',
#  1270523: 'Donal Hinley',
#  1270525: 'Fade to Black',
#  1270531: 'Idha',
#  1270553: 'Brian Eno & J.Peter Schwalm',
#  10597938: 'Os Guinness',
#  1270582: 'Krafy Kuts ft TC Izlam',
#  1148183: 'Primal',
#  1178845: 'Brian Whitman',
#  1270645: 'Nigel & Marvin',
#  6860018: 'In The Late 20th Century The Impossible Becomes Possible',
#  1270695: 'Pieta, Zoe & Constie Brown',
#  1148373: 'Charles Peguri',
#  1270772: 'Ungdumshälsan',
#  1195: 'Elvis Costello',
#  1040941: 'Project Wyze',
#  1086315: 'Ely Guerra',
#  1270858: 'Steve & Eydie',
#  1270867: 'De Niro',
#  1270894: 'Histeria',
#  1148713: 'Nura',
#  1270955: 'Suzanne Vega & Bill Frisell & Wayne Horvitz & Syd Straw',
#  1271008: 'The Realm',
#  7005783: 'Kiyommy + Seiya',
#  1271119: 'J Xaverre',
#  6992317: "MOND'RIEN",
#  6992318: 'チンポー',
#  ...}

# %% [markdown]
# We also use artist_alias.txt to map “bad” artist IDs to “good” ones, instead of just using it as raw data pairs of artist IDs. We convert bad IDs to good ones using the codes below. The first entry, for instance, maps ID 6803336 to 1000010, which means it maps “Aerosmith (unplugged)” to “Aerosmith.”

# %%
def aliaslookup(alias):
    splitPair = alias.rsplit('\t')
    if len(splitPair) != 2:
        return []
    else:
        try:
            return [(int(splitPair[0]), int(splitPair[1]))]
        except:
            return []
artistAlias = rawArtistAlias.flatMap(lambda x: aliaslookup(x)).collectAsMap()

# %%
artistAlias
# Out:
# {1027859: 1252408,
#  1017615: 668,
#  6745885: 1268522,
#  1018110: 1018110,
#  1014609: 1014609,
#  6713071: 2976,
#  1014175: 1014175,
#  1008798: 1008798,
#  1013851: 1013851,
#  6696814: 1030672,
#  1036747: 1239516,
#  1278781: 1021980,
#  2035175: 1007565,
#  1327067: 1308328,
#  2006482: 1140837,
#  1314530: 1237371,
#  1160800: 1345290,
#  1255401: 1055061,
#  1307351: 1055061,
#  1234249: 1005225,
#  6622310: 1094137,
#  1261919: 6977528,
#  2103190: 1002909,
#  9929875: 1009048,
#  2118737: 1011363,
#  9929864: 1000699,
#  6666813: 1305683,
#  1172822: 1127113,
#  2026635: 1001597,
#  6726078: 1018408,
#  1039896: 1277013,
#  1239168: 1266817,
#  6819291: 1277876,
#  2030690: 2060894,
#  6786886: 166,
#  1051692: 1307569,
#  1239193: 1012079,
#  1291581: 78,
#  6642817: 1010969,
#  1293171: 1007614,
#  1070350: 1034635,
#  6603691: 1279932,
#  1027851: 1063053,
#  2060513: 2029258,
#  1277348: 668,
#  1253023: 1033862,
#  1002892: 1002451,
#  2060435: 1256876,
#  6612396: 1301739,
#  1280154: 1021970,
#  6617155: 1039381,
#  1006102: 1034635,
#  6697417: 2013670,
#  1059007: 2653,
#  2101386: 2013670,
#  1098456: 1254644,
#  6633276: 1013675,
#  162: 1332522,
#  1246265: 1010669,
#  6708991: 1009773,
#  1000110: 1034635,
#  1002566: 1034635,
#  1001864: 1001864,
#  9929533: 1000088,
#  1289246: 1023527,
#  1261152: 1007206,
#  2113342: 1134530,
#  1016805: 3195,
#  1325227: 1246524,
#  1245064: 1264,
#  1015753: 1261449,
#  2164287: 10076841,
#  1044186: 10076841,
#  1006661: 1172842,
#  6639087: 974,
#  1028218: 1349406,
#  9928967: 15,
#  1269139: 1003505,
#  2150015: 1018408,
#  6611952: 1269012,
#  2134206: 1062330,
#  6893915: 1017065,
#  10345702: 1017065,
#  6880926: 1017065,
#  6873763: 1259700,
#  1231677: 1294194,
#  1333467: 1156425,
#  1169681: 1651,
#  1106289: 2093800,
#  6634844: 1018408,
#  2111668: 2085,
#  1038666: 1295935,
#  10112808: 3437,
#  9928973: 1000113,
#  10203303: 6618355,
#  1279723: 1007263,
#  1022552: 1249851,
#  2279441: 6834637,
#  1214254: 1262045,
#  1011272: 1246839,
#  10021668: 1250233,
#  6648707: 1088328,
#  1002139: 1018807,
#  1040536: 2073100,
#  1050544: 1002332,
#  6852428: 1035970,
#  1318457: 1002152,
#  1010410: 1013654,
#  1273591: 1598,
#  2144935: 1066433,
#  1000935: 6747938,
#  6603035: 1314538,
#  2073427: 1006475,
#  1305679: 1034635,
#  6723001: 2039323,
#  6612338: 1257158,
#  15: 15,
#  6843840: 1326,
#  1140506: 1271441,
#  1097968: 1004831,
#  9929045: 153,
#  1265244: 3122,
#  1010155: 1252957,
#  1246508: 1013471,
#  6666470: 1349406,
#  10328673: 1956,
#  3630: 6951848,
#  9919424: 234,
#  10013648: 733,
#  1185593: 1028908,
#  1030955: 5452,
#  1101433: 1755,
#  6979261: 1008583,
#  1199139: 166,
#  9929269: 1238242,
#  1323083: 1029530,
#  6652651: 1009454,
#  2684: 1002480,
#  1266264: 1286358,
#  1299041: 1034635,
#  10107676: 118,
#  6843503: 1257158,
#  10140618: 28,
#  1210088: 1104179,
#  6640761: 1254011,
#  1010284: 1018807,
#  1260442: 2060894,
#  1027472: 2036,
#  2085035: 1000236,
#  1156068: 1001859,
#  1211487: 1014738,
#  1123801: 1034202,
#  9929763: 1003778,
#  1327730: 6705745,
#  1016673: 1298111,
#  9910959: 1034635,
#  6644630: 1065358,
#  1146111: 1000123,
#  9929062: 1010646,
#  6666050: 1294194,
#  1104667: 1012935,
#  6747304: 4538,
#  1262727: 2176737,
#  9931068: 1003361,
#  1024502: 1009571,
#  6777696: 1047693,
#  1047140: 1277286,
#  1329111: 1023485,
#  1010145: 1249657,
#  1321574: 71,
#  1004857: 1034635,
#  2112240: 1246983,
#  1304801: 1307569,
#  10328618: 2814,
#  10227482: 1000200,
#  1341684: 71,
#  2036732: 71,
#  2034497: 71,
#  1338466: 71,
#  1351048: 71,
#  1339315: 71,
#  1009443: 1020059,
#  6927588: 1107395,
#  6755702: 1014604,
#  1037848: 1007201,
#  1321035: 1007201,
#  1051861: 1056268,
#  2066585: 1178346,
#  1003979: 1247540,
#  6606624: 1034635,
#  1210850: 2101375,
#  2154067: 1279924,
#  1292006: 1279924,
#  1100499: 1003448,
#  1159075: 1002152,
#  1016988: 1009571,
#  1300745: 5841,
#  6868142: 6866886,
#  1018155: 1015852,
#  6638483: 1195889,
#  1011730: 1239504,
#  1009499: 6730533,
#  1014145: 1009646,
#  1212985: 1301739,
#  9929600: 1004129,
#  1280087: 1295531,
#  6704224: 9964755,
#  1071257: 1236897,
#  1060739: 1263049,
#  6645431: 1013510,
#  1126370: 2114258,
#  10328567: 1000689,
#  9997128: 4303,
#  1214221: 1021115,
#  6752624: 684,
#  6843863: 1326,
#  10163001: 4775,
#  1244701: 1249401,
#  1330987: 1056296,
#  1038051: 6684730,
#  1007834: 1237371,
#  1293474: 1006885,
#  2099786: 2048617,
#  1302130: 1291109,
#  6738758: 2106357,
#  9929441: 1307,
#  1013011: 1276641,
#  6623536: 9916985,
#  6606825: 1014175,
#  2017616: 1007864,
#  1291230: 1236346,
#  1286507: 1137423,
#  6935408: 4349,
#  6689505: 1001655,
#  1023449: 1310185,
#  2009180: 6751847,
#  1109974: 1007063,
#  10079136: 1002328,
#  1099602: 2966,
#  1015298: 1247152,
#  9931148: 1006896,
#  6666533: 1253307,
#  6667192: 1086117,
#  1080914: 1274829,
#  1003801: 1241757,
#  1049704: 1261464,
#  10092575: 1000028,
#  1334929: 1246709,
#  1291110: 1030060,
#  1055562: 1276662,
#  1090594: 1009633,
#  1252764: 1003014,
#  2058402: 1024619,
#  1029677: 9983203,
#  6671271: 1033631,
#  1327919: 9983203,
#  6827946: 9983203,
#  1270553: 1327696,
#  1000945: 1018807,
#  6786145: 300,
#  6614668: 7006467,
#  10331634: 1000048,
#  9912102: 1034635,
#  1065198: 2061677,
#  1351750: 1233610,
#  1307528: 2036704,
#  1012315: 1238836,
#  1314904: 6977528,
#  1053693: 1170206,
#  1287055: 1020615,
#  7023179: 5696,
#  6963887: 1013095,
#  1252485: 1010725,
#  1079065: 1236703,
#  1027126: 1255783,
#  1274317: 1234387,
#  1012803: 2161899,
#  6666213: 3554,
#  1298276: 6875510,
#  1234344: 1012125,
#  10055114: 2051723,
#  10377598: 1010055,
#  1033104: 1027610,
#  2179213: 1111915,
#  6730134: 1271216,
#  1301746: 1056258,
#  1017322: 1277866,
#  1045804: 1247516,
#  1152469: 1009402,
#  2140188: 10334513,
#  1291960: 1266817,
#  2059804: 1008487,
#  6708740: 1089337,
#  1101793: 1044253,
#  1047491: 1003342,
#  1049384: 1008336,
#  1059884: 1288727,
#  6873850: 1300642,
#  2067429: 1034635,
#  2069589: 1234503,
#  10237528: 1235384,
#  1027009: 2004228,
#  6751850: 2070071,
#  6607841: 1015122,
#  6606625: 1034635,
#  1052722: 2797,
#  6688903: 6706174,
#  6892355: 6785079,
#  6618608: 6785079,
#  1019819: 1034635,
#  9929669: 1004347,
#  6606757: 1003888,
#  2140558: 2114264,
#  6730231: 2161931,
#  1075482: 1264703,
#  2064333: 1076507,
#  1022108: 1035334,
#  6759209: 1241695,
#  1008416: 242,
#  10263339: 1008093,
#  1276810: 420,
#  6622876: 2161595,
#  6670816: 2051861,
#  1254235: 1254644,
#  1305341: 1010658,
#  1039314: 1203762,
#  9919711: 9956508,
#  2082135: 1259297,
#  6635073: 1259297,
#  1300796: 2036,
#  6619918: 2140107,
#  1258892: 1244746,
#  6662497: 1327588,
#  6882695: 1013167,
#  1245000: 1028445,
#  5702: 1066440,
#  1007480: 1012243,
#  1244982: 1028445,
#  1122437: 1254299,
#  2075188: 10150610,
#  1073470: 1327647,
#  10270142: 10096874,
#  9954151: 779,
#  1275001: 1028445,
#  1244994: 1028445,
#  1122824: 2148043,
#  1084265: 1065358,
#  2140580: 1002672,
#  2070673: 1169482,
#  1010636: 1239101,
#  1031417: 1265996,
#  1033536: 1008824,
#  1006162: 1048788,
#  1179492: 1246136,
#  2113453: 1003052,
#  2052613: 1088572,
#  1279110: 2035089,
#  10314684: 6716462,
#  1042508: 1008824,
#  10176206: 1014716,
#  6657341: 10361613,
#  1283015: 1001230,
#  1289264: 1013714,
#  1033391: 1239278,
#  2082602: 1043147,
#  1052982: 1011231,
#  2036251: 2043827,
#  2020235: 1246136,
#  1271924: 1018769,
#  1039828: 1018807,
#  1039174: 1075543,
#  9918754: 4497,
#  1235697: 1233982,
#  1244970: 1028445,
#  6843877: 1326,
#  1115653: 1249252,
#  1127341: 1252111,
#  1012852: 6696725,
#  1130370: 2235,
#  1245134: 1007263,
#  1036143: 1063053,
#  6790420: 2129177,
#  1263808: 2070227,
#  6620802: 4377,
#  1181082: 1009583,
#  1203592: 1156425,
#  1024571: 1029592,
#  1029799: 1156425,
#  1016343: 1014340,
#  754: 754,
#  1016631: 1006736,
#  1138014: 1034635,
#  1002778: 393,
#  1253088: 1238269,
#  6933178: 809,
#  1011293: 1489,
#  6965760: 1027610,
#  1010760: 1239516,
#  1006322: 1006322,
#  1006347: 1006347,
#  1058622: 1251812,
#  6742353: 2104058,
#  6718488: 1059264,
#  1281865: 1011316,
#  1006140: 1246817,
#  1015584: 1007658,
#  9919044: 2007,
#  9937566: 809,
#  9937520: 1147975,
#  1275359: 1287322,
#  2061602: 6748393,
#  6642370: 1049114,
#  1010872: 2439,
#  2126687: 1023928,
#  9930422: 1002619,
#  1000129: 5810,
#  1092585: 1002559,
#  1303182: 6837566,
#  10586534: 1008953,
#  1017671: 1015311,
#  1025954: 2040456,
#  1271505: 1003694,
#  1322886: 2105178,
#  6895260: 1308328,
#  1278418: 1255555,
#  1340193: 2797,
#  2155515: 1003105,
#  1022439: 4609,
#  6632852: 1001835,
#  2100392: 1012457,
#  1108824: 1007415,
#  9929214: 1233948,
#  6703817: 1006812,
#  1007631: 1235753,
#  1039492: 1269417,
#  6926874: 1014485,
#  1002498: 3066,
#  1097119: 1016561,
#  1008455: 1020,
#  1286284: 5630,
#  1266371: 1236703,
#  6779861: 1250104,
#  2025676: 1001141,
#  1023217: 2076786,
#  1011160: 1238478,
#  1340980: 1000602,
#  1006268: 1002392,
#  1197558: 1001943,
#  1340959: 1000602,
#  6677859: 670,
#  2066701: 1063426,
#  1327070: 1341919,
#  10050528: 831,
#  1015209: 1167955,
#  1192222: 1025647,
#  1020004: 1025647,
#  6814996: 1002912,
#  1086572: 1233677,
#  1138325: 2023771,
#  1139033: 1011219,
#  1050349: 1043653,
#  4421: 1252779,
#  6703227: 1210979,
#  1070459: 2064199,
#  709: 2003588,
#  6843892: 1012077,
#  1012388: 1254487,
#  6625714: 1060179,
#  6901494: 1006485,
#  6806131: 1002061,
#  1284393: 887,
#  1023197: 1269447,
#  6604494: 6834637,
#  2131963: 1020,
#  10504380: 1070177,
#  2279509: 1322366,
#  1002670: 1034635,
#  1143149: 1093353,
#  6934479: 1256115,
#  9947015: 1292207,
#  2147002: 10077841,
#  1278109: 1036654,
#  9929574: 1008086,
#  1061384: 1252912,
#  6935936: 3016,
#  2159997: 1003313,
#  1044729: 1046148,
#  1067417: 1003694,
#  1270359: 1019163,
#  1102968: 1233982,
#  1030009: 1791,
#  6766073: 1006837,
#  1026989: 1033119,
#  1267504: 1007885,
#  1134651: 659,
#  1006146: 1031646,
#  1157380: 1018266,
#  1047433: 1054273,
#  6895364: 2153903,
#  6812143: 1017092,
#  1104448: 1008824,
#  1246003: 4185,
#  1255551: 1266817,
#  1326264: 1235663,
#  2164170: 1247118,
#  6923988: 2140107,
#  6606823: 1267774,
#  10198357: 1025721,
#  10014536: 1009583,
#  1038011: 718,
#  9952803: 1156794,
#  1248351: 1007614,
#  1293301: 1001307,
#  1033265: 1136358,
#  9967716: 1015426,
#  1106946: 1006039,
#  1233934: 1234700,
#  6704508: 1006919,
#  6804942: 6676351,
#  2025457: 951,
#  1112427: 1080556,
#  1089486: 1090808,
#  1139806: 1039249,
#  1006788: 1003221,
#  6677618: 1028295,
#  2166168: 2025147,
#  1059441: 1039249,
#  2164352: 6922812,
#  6607809: 1034635,
#  2008447: 1034635,
#  1028259: 1237408,
#  1257324: 1240486,
#  1129917: 1039249,
#  2162103: 3195,
#  6827283: 3195,
#  6835354: 1039381,
#  2031207: 2031502,
#  1022183: 938,
#  1067365: 1003694,
#  1344818: 1331984,
#  2008155: 1007801,
#  1011370: 1246174,
#  1089639: 1003694,
#  1023269: 1253188,
#  1033184: 1006320,
#  6801236: 1013362,
#  1130780: 1319532,
#  6793156: 1319489,
#  1240531: 1078983,
#  1005489: 2003588,
#  1116245: 1003556,
#  6621334: 1012031,
#  1059744: 1254973,
#  1079120: 1000655,
#  6972279: 1000985,
#  6985668: 6992655,
#  1078613: 2017,
#  1234308: 59,
#  9929753: 1007347,
#  1009440: 1003272,
#  10383606: 1319489,
#  10713370: 1084235,
#  10713436: 6611448,
#  1022947: 6951566,
#  1197153: 1018406,
#  1145243: 2115937,
#  1008020: 1277876,
#  1006577: 1261516,
#  1007949: 1045811,
#  1241896: 1045811,
#  6818610: 1233623,
#  6703268: 1260159,
#  6843530: 1260159,
#  9974891: 1260159,
#  1033242: 1000655,
#  2159316: 1034635,
#  1289361: 1262825,
#  6679381: 1027349,
#  6827288: 1238056,
#  1312285: 1039017,
#  1012932: 1234727,
#  1071225: 1027595,
#  1070722: 930,
#  1110471: 1007075,
#  10052696: 1116214,
#  1063100: 1057539,
#  1208053: 1060179}

# %% [markdown]
# # Build a model

# %% [markdown]
# We then create a lookup function to convert the data into Rating objects. Note that any underlying MLlib models would need products as an objective measure. In our model, the products are artists. We will therefore use user_artist_data.txt for implementing our train data.

# %%
bArtistAlias = sc.broadcast(artistAlias)

# %%
def ratinglookup(x):
    userID, artistID, count = map(lambda line: int(line), x.split())
    finalArtistID = bArtistAlias.value.get(artistID)
    if finalArtistID is None:
        finalArtistID = artistID
    return Rating(userID, finalArtistID, count)
trainData = rawUserArtistData.map(lambda x: ratinglookup(x))
trainData.cache()
# Out:
# PythonRDD[8] at RDD at PythonRDD.scala:53

# %%
trainData.take(10)
# Out:
# [Rating(user=1059637, product=1000010, rating=238.0),
#  Rating(user=1059637, product=1000049, rating=1.0),
#  Rating(user=1059637, product=1000056, rating=1.0),
#  Rating(user=1059637, product=1000062, rating=11.0),
#  Rating(user=1059637, product=1000094, rating=1.0),
#  Rating(user=1059637, product=1000112, rating=423.0),
#  Rating(user=1059637, product=1000113, rating=5.0),
#  Rating(user=1059637, product=1000114, rating=2.0),
#  Rating(user=1059637, product=1000123, rating=2.0),
#  Rating(user=1059637, product=1000130, rating=19129.0)]

# %% [markdown]
# Finally, we build our model using collaborative filtering algorithm as follows. The operation will likely take minutes or more depending on your cluster. It took me around 15 minutes to run the model.

# %%
model = ALS.trainImplicit(trainData, 10, 5)

# %% [markdown]
# We should first see if the artist recommendations make any intuitive sense, by examining a user, his or her plays, and recommendations for that user. Take, for example, user 2093760. Extract the IDs of artists that this user has listened to and print their names. This means searching the input for artist IDs for this user, and then filtering the set of artists by these IDs so you can collect and print the names in order:

# %%
spotcheckingID = 1059637
bArtistByID = sc.broadcast(artistByID)
rawArtistsForUser = (trainData
                  .filter(lambda x: x.user == spotcheckingID)
                  .map(lambda x: bArtistByID.value.get(x.product))
                  .collect())
print(rawArtistsForUser)
# Out:
# ['Aerosmith', "Edna's Goldfish", 'The Mighty Mighty Bosstones', 'Foo Fighters', 'The Bouncing Souls', 'Alkaline Trio', 'The Beatles', 'Pennywise', 'Incubus', 'Bright Eyes', 'Muse', 'Jason Mraz', 'Jimmy Eat World', 'Meat Loaf', 'The Lightning Seeds', 'MxPx', 'At the Drive-In', 'New Found Glory', 'Blind Melon', 'Chicago', 'Hoobastank', 'Loreena McKennitt', 'Moulin Rouge', 'Goo Goo Dolls', 'Spin Doctors', 'Dave Matthews Band', 'Cast', 'Mundy', 'Ben Kweller', 'Wham!', 'Third Eye Blind', 'Sugarcult', 'The Ataris', 'Descendents', 'Strung Out', 'The Muffs', 'Kenny Loggins', 'Fountains of Wayne', 'Sheryl Crow', 'The Cranberries', 'blink-182', 'OMC', 'Funeral for a Friend', 'Finch', 'Saves the Day', 'The Starting Line', 'Modest Mouse', 'Simple Minds', 'A Flock Of Seagulls', 'The Hippos', 'Something Corporate', 'Taking Back Sunday', 'The Movielife', 'The Darkness', 'Phantom Planet', 'Sunny Day Real Estate', 'Saturday Night Live', 'Guster', 'Good Charlotte', 'Cyndi Lauper', 'Nena', '[unknown]', 'Hot Rod Circuit', 'Catch 22', 'RX Bandits', 'Glassjaw', 'Andrew W.K.', 'Billy Joel', 'Dashboard Confessional', 'Liam Lynch', 'Mindless Self Indulgence', 'Tears for Fears', 'Prince', 'The Mars Volta', 'Spice Girls', 'Yeah Yeah Yeahs', 'hellogoodbye', 'Les Savy Fav', 'Clint Mansell', 'Dead Poetic', 'Yellowcard', 'The All-American Rejects', 'Brand New', 'Thursday', 'Thrice', 'Home Grown', 'The Von Bondies', 'Nicky Holland', 'The Used', 'Justin Timberlake', 'Marvin Gaye & Tammi Terrell', 'Vince Guaraldi Trio', 'Motion City Soundtrack', 'Converge', 'Blues Traveler', 'Cursive', 'Spoon', 'Harry Nilsson', 'Grade', 'Rilo Kiley', 'Imperial Teen', 'Just Jack', 'Pedro the Lion', 'Built to Spill', 'Norma Jean', 'Onelinedrawing', 'Strike Anywhere', 'Fairweather', 'A Static Lullaby', 'Coheed and Cambria', 'Brandtson', 'Further Seems Forever', 'From Autumn to Ashes', 'Hey Mercedes', 'Hopesfall', 'Underoath', 'Noise Ratchet', 'Jawbreaker', 'Newsies', 'Glasseater', 'Atmosphere', 'Hot Hot Heat', 'Hum', 'Maroon 5', 'DDR', 'Frou Frou', 'Morning Call', 'No Motiv', 'Piebald', 'Hanson', '3 Day Weekend', 'Mae', 'Lynyrd Skynyrd', 'Scraps And Heartattacks', "Ebaum's World", 'Norman Greenbaum', 'Against Me!', 'Remy Zero', 'MC Chris', 'Aqua Teen Hunger Force', 'Jann Arden', 'Jimmy Soul', 'Tony Bennett', 'Kelly Clarkson', 'Streetlight Manifesto', 'Strong Bad', 'Mary Chapin Carpenter', 'Rise Against', 'Jill Sobule', 'Colin Hay', 'Copeland', 'Maurice Ravel', 'Homestar Runner', 'Kill Hannah', 'Allister', 'Grease', 'Senses Fail', '1208', 'This Day Forward', 'Klaus Badelt', 'Velocity Girl', 'Armor for Sleep', 'Usher', 'Tiffany', 'Boys Night Out', 'Dane Cook', 'FUNNY SONGS', 'Punchline', 'James Newton Howard', 'Fall Out Boy', 'Every Time I Die', 'David Daniels, Ensemble Orchestral de Paris & John Nelson', 'My Chemical Romance', 'Story of the Year', 'Blaque', 'Alexisonfire', 'Say Anything', 'Moneen', 'Trevor Rabin', 'Halifax', 'ilya', 'Jonathan Larson', 'Hilary Duff', 'Vic Chesnutt', 'Jackie De Shannon', 'A Trunk Full Of Dead Bodies', 'Leon Russell', 'Terror Squad', 'Matchbook Romance', 'Mitch Hedberg', 'Jon Dee Graham', 'MUSICMATCH', 'Time In Malta', 'breaking pangaea', 'Bayside', 'Gwen Stefani', 'Emocapella', 'Anadivine', 'maxeen', 'Jamison', 'Hidden in Plain View', 'Misery Signals', 'Cordero', 'Denver Harbor', 'Sarcasm', 'Give up the Ghost', 'Fear Before the March of Flames', 'Mr. C', 'Ryan Cabrera', 'Fallout Boy', 'Murder by Death', 'Tilly and the Wall', 'Liars Academy', 'Amanda Rogers', 'Letter Kills', 'Jet', 'Eisley', 'Bear Vs. Shark', 'Nevea Tears', 'Coldplay', 'NearMiss', 'Socratic', 'Electric Light Orchestra', 'Elliott Smith', 'Head Automatica', 'U2', 'Ima Robot', 'Beastie Boys', 'Franz Ferdinand', 'The Early November', 'The Faint', 'The Postal Service', 'The Rocket Summer', 'The Bled', 'The Decemberists', 'The American Analog Set', 'The Lawrence Arms', 'The Shins', 'The Temptations', 'Ike & Tina Turner', 'The Hollies', 'The Vapors', 'The Kinison', 'The Who', 'The Hope Cons ...

# %%
recommendations = map(lambda x: artistByID.get(x.product), model.call("recommendProducts", spotcheckingID, 10))
print(list(recommendations))
# Out:
# ['Green Day', 'My Chemical Romance', 'The Starting Line', 'Something Corporate', 'Bright Eyes', 'Taking Back Sunday', 'Straylight Run', 'New Found Glory', 'Thrice', 'Incubus']
